# %%
import os
import pandas as pd
import requests
from gprofiler import GProfiler  # Ensure you have installed gprofiler-official
from RAG_workflow import initialize_gene_list, extract_gene_descriptions

def query_gprofiler_rest(genes, organism="rnorvegicus", user_threshold=0.05):
    url = "https://biit.cs.ut.ee/gprofiler/api/gost/profile/"
    sources = ["GO:BP", "GO:MF", "GO:CC", "KEGG", "REAC"]
    payload = {
        "organism": organism,
        "query": genes,
        "user_threshold": user_threshold,
        "sources": sources,
        "significance_threshold_method": "g_SCS",
        "no_iea": False,
        "domain_scope": "annotated",
        "output": "json",
        "no_evidences": False
    }
    headers = {"User-Agent": "FullPythonRequest"}
    response = requests.post(url, json=payload, headers=headers)
    response.raise_for_status()
    data = response.json()
    df = pd.DataFrame(data["result"])
    return df

def query_gprofiler(genes, organism="rnorvegicus", user_threshold=0.05):
    gp = GProfiler(return_dataframe=True)
    sources = ["GO:BP", "GO:MF", "GO:CC", "KEGG", "REAC"]
    res = gp.profile(
        organism=organism,
        query=genes,
        user_threshold=user_threshold,
        sources=sources,
        significance_threshold_method="g_SCS",
        no_iea=False,
        domain_scope="annotated",
        no_evidences=False
    )
    if "intersection" in res.columns:
        res.rename(columns={"intersection": "intersections"}, inplace=True)
    return res

def filter_best_per_parent(df):
    required_cols = {'p_value', 'parents', 'native'}
    if not required_cols.issubset(df.columns):
        return df
    df_sorted = df.sort_values(by='p_value', ascending=True).reset_index(drop=True)
    kept_terms = set()
    rows_to_keep = []
    for idx, row in df_sorted.iterrows():
        term_id = row['native']
        parent_ids = row['parents'] if isinstance(row['parents'], list) else []
        if any(parent in kept_terms for parent in parent_ids):
            continue
        rows_to_keep.append(idx)
        kept_terms.add(term_id)
    return df_sorted.loc[rows_to_keep].sort_values(by='p_value', ascending=True)

if __name__ == "__main__":
    gene_list_string, regulation, num_genes = initialize_gene_list()
    print(f"Number of genes: {num_genes}")
    gene_descriptions = extract_gene_descriptions(gene_list_string)
    
    genes = [gene.strip() for gene_list in gene_list_string.split(',') 
             for gene in gene_list.split() if gene.strip()]
    
    if genes:
        try:
            df_pkg = query_gprofiler(genes=genes, organism="rnorvegicus", user_threshold=0.05)
            
            df_api = query_gprofiler_rest(genes=genes, organism="rnorvegicus", user_threshold=0.05)
            df_api_sig = df_api[df_api["p_value"] < 0.05].copy()
            df_api_best = filter_best_per_parent(df_api_sig)
            
            df_api_best.rename(columns={
                "name": "Pathway", 
                "native": "annotation term", 
                "p_value": "p-value"
            }, inplace=True)
            
            df_merged = pd.merge(
                df_api_best,
                df_pkg[['native', 'intersections']],
                left_on="annotation term",
                right_on="native",
                how="left",
                suffixes=('_api', '_pkg')
            )
            df_merged.drop(columns=["native"], inplace=True, errors='ignore')
            
            if 'intersections_pkg' in df_merged.columns:
                df_merged['genes'] = df_merged['intersections_pkg'].apply(
                    lambda x: ', '.join(x) if isinstance(x, list) else x if pd.notnull(x) else ''
                )
            else:
                df_merged['genes'] = df_merged['intersections_api'].apply(
                    lambda x: ', '.join(x) if isinstance(x, list) else x if pd.notnull(x) else ''
                )
            
            df_final = df_merged[["Pathway", "description", "annotation term", "source", "p-value", "genes"]]
            
            output_path = "./output/text_files/ground_truth_pathways.txt"
            df_final[["Pathway", "annotation term", "genes"]].to_csv(output_path, sep="\t", index=False)
            print(f"Output written to {output_path}")
            
        except requests.HTTPError as e:
            print(f"HTTP error occurred: {e}")
        except Exception as e:
            print(f"An error occurred: {e}")
# Out:
# Number of genes: 250
# Total genes to process: 250
# Genes: {'Nrp1', 'Kif1a', 'Pmp22', 'Magea9', 'Taf9b', 'Inpp5a', 'Cpe', 'Chst2', 'Manba', 'Vps26c', 'Ecel1', 'Ckap4', 'Icoslg', 'Defb29', 'Slitrk6', 'Cd9', 'Bgn', 'Tspan5', 'Trim35', 'Col15a1', 'Pals1', 'Nlrp1a', 'Piezo2', 'Prss12', 'Ighm', 'Parm1', 'Fam20c', 'Hmx3', 'Cdca7l', 'Serpini1', 'Map1lc3a', 'Snx4', 'Pltp', 'Gldn', 'Stard13', 'Aig1', 'Prss23', 'A2m', 'Selplg', 'Wnt5a', 'Cxcl14', 'Sema4f', 'Col20a1', 'Man1a1', 'Myo1d', 'Acta2', 'Ltbp1', 'Psmd2', 'Igfbp3', 'Tril', 'Sema3g', 'Serinc5', 'Ppp1r14c', 'Cep295nl', 'Cpm', 'Tent5c', 'Plxnb1', 'Rcn3', 'Synpr', 'Tpcn1', 'Lef1', 'Adamts17', 'Cobll1', 'Vopp1', 'Sgpl1', 'Grb14', 'Magea4', 'Dhrs1', 'Tex101', 'Sipa1l1', 'Gtf2e1', 'Steap1', 'Hsp90aa1', 'Nfatc1', 'Ntn1', 'Mybl1', 'Emilin1', 'Gja1', 'Ppfia4', 'Rnf144a', 'Hadhb', 'Parp14', 'Ano5', 'Tagln', 'Hspa12a', 'Peg3', 'P2ry2', 'Gprc5b', 'Cpsf2', 'Msi1', 'Ctbs', 'Cxcl12', 'Mfap5', 'Pfn2', 'St3gal5', 'Abcb4', 'Tbccd1', 'Phldb2', 'Pgm1', 'Klhdc2', 'Tuba4a', 'Zfyve28', 'Marveld1', 'Matn3', 'Gypc', 'Col9a3', 'Mageb16', 'Aldh1a1', 'Frrs1', 'Lifr', 'Ifnar1', 'Psap', 'Col8a2', 'ENSRNOG00000063649', 'Slc9a9', 'Lrrtm3', 'Slit2', 'Hs6st2', 'Eif2ak2', 'Arsg', 'Hapln1', 'Nampt', 'Scn7a', 'Krtap1-5', 'Gcnt1', 'Tnik', 'Sbspon', 'Nrp2', 'Ghr', 'Runx3', 'Riox2', 'Aff3', 'Igf2bp2', 'Tf', 'Arsb', 'Mpz', 'Rhoj', 'Apod', 'Ppm1f', 'Steap2', 'Dpysl5', 'Sncg', 'Fbxo11', 'Klhl29', 'Met', 'Msh2', 'Robo2', 'Abca8a', 'Nes', 'Aif1l', 'Tspan4', 'Stk39', 'Mag', 'Sumo3', 'Cldn19', 'Prx', 'Pappa', 'Septin4', 'Sqor', 'Fhod3', 'Itpripl1', 'Ppp1r36', 'Hs6st1', 'Agpat5', 'Atf3', 'Asap1', 'Pkp1', 'Alpl', 'Klf9', 'Emp2', 'Gprc5a', 'Tmem26', 'Qsox1', 'Slc22a17', 'Papola', 'Mal', 'Tnfrsf1a', 'Septin5', 'Rab10', 'Adamtsl3', 'Olfm2', 'Ryr3', 'Efna5', 'Pnpt1', 'Id2', 'Col11a1', 'Tubb4a', 'Serpinf1', 'Vash1', 'Ppard', 'Drp2', 'Rrm2', 'Cdh13', 'Slc35a2', 'Atf5', 'Ddx1', 'Itga8', 'Ptgfr', 'Cenpo', 'Pam', 'Clca4l', 'Srgap1', 'Cggbp1', 'Gnai1', 'ENSRNOG00000062503', 'Prkar2b', 'Pcsk5', 'Ccn4', 'Smc6', 'Fth1', 'Gpnmb', 'Magec2l1', 'Ptrh1', 'Cntn6', 'Fut10', 'Poglut1', 'Olfml1', 'Adamtsl1', 'Mef2c', 'Nrbp1', 'Dyrk1a', 'Slco3a1', 'Dpysl3', 'Bace2', 'C1qtnf1', 'Snx6', 'Nek9', 'Htra1', 'Cd151', 'Vrk1', 'Acap2', 'Slc39a13', 'Numb', 'Prkd3', 'Chmp2b', 'Gldc', 'Vps8', 'Itga7', 'Has2', 'Lrp2', 'Timp1', 'Ebf1', 'Zpld1', 'Pxdn', 'Epas1', 'Efemp2', 'Ccn3', 'Cldnd1', 'Cers6', 'Zfp518a'}
# The following genes were not found in the gene data file: ENSRNOG00000063649, ENSRNOG00000062503
# Output written to ./output/text_files/ground_truth_pathways.txt

# %%
df_final
# Out:
#                                               Pathway  \
# 0                                      cell periphery
# 1                    multicellular organismal process
# 2                                extracellular region
# 3                         regulation of cell motility
# 4                                  system development
# 5                            regulation of locomotion
# 6                                          locomotion
# 7                    anatomical structure development
# 8                                      cell migration
# 9                                             vesicle
# 10                              developmental process
# 11                                      cell motility
# 12                                    protein binding
# 13                                endomembrane system
# 14                      response to external stimulus
# 15                               extracellular matrix
# 16          positive regulation of biological process
# 17                  Extracellular matrix organization
# 18                                      Axon guidance
# 19                                          cytoplasm
# 20                         blood vessel morphogenesis
# 21                                           membrane
# 22   enzyme-linked receptor protein signaling pathway
# 23                                   integrin binding
# 24                                 tube morphogenesis
# 25                                      cell adhesion
# 26                    response to endogenous stimulus
# 27                      extracellular matrix assembly
# 28                   regulation of biological quality
# 29                  extracellular matrix organization
# 30      external encapsulating structure organization
# 31               extracellular structure organization
# 32            cell surface receptor signaling pathway
# 33      regulation of cellular component organization
# 34                 regulation of response to stimulus
# 35                                       localization
# 36                        somatodendritic compartment
# 37           regulation of endothelial cell migration
# 38             olfactory bulb interneuron development
# 39  negative regulation of cell projection organiz...
# 40                               tissue morphogenesis
# 41                               cell-matrix adhesion
# 42                               response to chemical
# 43        cellular response to growth factor stimulus
# 44                                 embryo development
# 45                                apical part of cell
# 46           axon extension involved in axon guidance
# 47  neuron projection extension involved in neuron...
# 48                     bounding membrane of organelle
# 49                            regulation of signaling
# 50                   regulation of cell communication
# 51                               response to stimulus
# 52                                      myelin sheath
# 53                                negative chemotaxis
# 54                                     early endosome
#
#                                           description     annotation term  \
# 0   "The broad region around and including the pla...          GO:0071944
# 1   "Any biological process, occurring at the leve...          GO:0032501
# 2   "The space external to the outermost structure...          GO:0005576
# 3   "Any process that modulates the frequency, rat...          GO:2000145
# 4   "The process whose specific outcome is the pro...          GO:0048731
# 5   "Any process that modulates the frequency, rat...          GO:0040012
# 6   "Self-propelled movement of a cell or organism...          GO:0040011
# 7   "The biological process whose specific outcome...          GO:0048856
# 8   "The controlled self-propelled movement of a c...          GO:0016477
# 9   "Any small, fluid-filled, spherical organelle ...          GO:0031982
# 10  "A biological process whose specific outcome i...          GO:0032502
# 11  "Any process involved in the controlled self-p...          GO:0048870
# 12          "Binding to a protein." [GOC:go_curators]          GO:0005515
# 13  "A collection of membranous structures involve...          GO:0012505
# 14  "Any process that results in a change in state...          GO:0009605
# 15  "A structure lying external to one or more cel...          GO:0031012
# 16  "Any process that activates or increases the f...          GO:0048518
# 17                  Extracellular matrix organization  REAC:R-RNO-1474244
# 18                                      Axon guidance          KEGG:04360
# 19  "The contents of a cell excluding the plasma m...          GO:0005737
# 20  "The process in which the anatomical structure...          GO:0048514
# 21  "A lipid bilayer along with all the proteins a...          GO:0016020
# 22  "The series of molecular signals initiated by ...          GO:0007167
# 23                "Binding to an integrin." [GOC:ceb]          GO:0005178
# 24  "The process in which the anatomical structure...          GO:0035239
# 25  "The attachment of a cell, either to another c...          GO:0007155
# 26  "Any process that results in a change in state...          GO:0009719
# 27  "The aggregation, arrangement and bonding toge...          GO:0085029
# 28  "Any process that modulates a qualitative or q...          GO:0065008
# 29  "A process that is carried out at the cellular...          GO:0030198
# 30  "A process that is carried out at the cellular...          GO:0045229
# 31  "A process that is carried out at the cellular...          GO:0043062
# 32  "The series of molecular signals initiated by ...          GO:0007166
# 33  "Any process that modulates the frequency, rat...          GO:0051128
# 34  "Any process that modulates the frequency, rat...          GO:0048583
# 35  "Any process in which a cell, a substance, or ...          GO:0051179
# 36  "The region of a neuron that includes the cell...          GO:0036477
# 37  "Any process that modulates the rate, frequenc...          GO:0010594
# 38  "The process whose specific outcome is the pro...          GO:0021891
# 39  "Any process that stops, prevents, or reduces ...          GO:0031345
# 40  "The process in which the anatomical structure...          GO:0048729
# 41  "The binding of a cell to the extracellular ma...          GO:0007160
# 42  "Any process that results in a change in state...          GO:0042221
# 43  "Any process that results in a change in state...          GO:0071363
# 44  "The process whose specific outcome is the pro...          GO:0009790
# 45  "The region of a polarized cell that forms a t...          GO:0045177
# 46  "The long distance growth of a single cell pro...          GO:0048846
# 47  "Any neuron projection extension that is invol...          GO:1902284
# 48  "The lipid bilayer that forms the outer-most l...          GO:0098588
# 49  "Any process that modulates the frequency, rat...          GO:0023051
# 50  "Any process that modulates the frequency, rat...          GO:0010646
# 51  "Any process that results in a change in state...          GO:0050896
# 52  "An electrically insulating fatty layer that s...          GO:0043209
# 53  "The directed movement of a motile cell or org...          GO:0050919
# 54  "A membrane-bounded organelle that receives in...          GO:0005769
#
#    source       p-value                                              genes
# 0   GO:CC  4.299074e-13  Cntn6, Prss12, Tex101, Sema4f, Hapln1, Parm1, ...
# 1   GO:BP  3.928781e-10  Aldh1a1, Pcsk5, Cpe, Col9a3, Emp2, Acta2, Igfb...
# 2   GO:CC  2.623669e-09  Prss12, Pcsk5, Tex101, Qsox1, Htra1, Igfbp3, A...
# 3   GO:BP  1.567922e-08  Pcsk5, Tex101, Emp2, Chst2, Igfbp3, Ccn3, Ntn1...
# 4   GO:BP  2.075100e-08  Aldh1a1, Pcsk5, Cpe, Col9a3, Emp2, Acta2, Ccn3...
# 5   GO:BP  4.528831e-08  Pcsk5, Tex101, Emp2, Chst2, Igfbp3, Ccn3, Ntn1...
# 6   GO:BP  9.629089e-08  Pcsk5, Tex101, Emp2, Chst2, Igfbp3, Ccn3, Ntn1...
# 7   GO:BP  1.221614e-07  Aldh1a1, Pcsk5, Cpe, Col9a3, Emp2, Acta2, Htra...
# 8   GO:BP  3.510191e-07  Pcsk5, Emp2, Chst2, Igfbp3, Ccn3, Ntn1, Cxcl14...
# 9   GO:CC  4.542548e-07  Prss12, Tex101, Qsox1, Cpe, Parm1, Emp2, Synpr...
# 10  GO:BP  5.691427e-07  Aldh1a1, Pcsk5, Cpe, Col9a3, Emp2, Acta2, Htra...
# 11  GO:BP  9.196980e-07  Pcsk5, Tex101, Emp2, Chst2, Igfbp3, Ccn3, Ntn1...
# 12  GO:MF  1.083946e-06  Cntn6, Cobll1, Sema4f, Cpe, Tuba4a, Emp2, Acta...
# 13  GO:CC  1.211521e-06  Pcsk5, Tex101, Qsox1, Sema4f, Cpe, Parm1, Emp2...
# 14  GO:BP  2.297099e-06  Zpld1, Acta2, Tril, A2m, Ccn3, Defb29, Ntn1, P...
# 15  GO:CC  2.362395e-06  Hapln1, Ltbp1, Ntn1, Mfap5, Pxdn, Matn3, Efemp...
# 16  GO:BP  7.908000e-06  Cntn6, Aldh1a1, Pcsk5, Emp2, Chst2, Igfbp3, Tr...
# 17   REAC  8.642243e-06  Hapln1, Col9a3, A2m, Cep295nl, Mfap5, Pxdn, Ma...
# 18   KEGG  1.423045e-05  Sema4f, Ntn1, Srgap1, Nrp1, Robo2, Slit2, Gnai...
# 19  GO:CC  2.970568e-05  Prss12, Pcsk5, Tex101, Qsox1, Sema4f, Cpe, Par...
# 20  GO:BP  5.417253e-05  Emp2, Ccn3, Pxdn, Nrp1, Cdh13, Epas1, Serpinf1...
# 21  GO:CC  5.396448e-04  Cntn6, Prss12, Pcsk5, Tex101, Qsox1, Sema4f, C...
# 22  GO:BP  7.101388e-04  Htra1, Igfbp3, Ccn3, Grb14, Ltbp1, Nrp1, Cdh13...
# 23  GO:MF  9.228835e-04  Emp2, Ccn3, Tspan4, Cd9, Emilin1, Cd151, Cxcl1...
# 24  GO:BP  1.744178e-03  Emp2, Ccn3, Ntn1, Pxdn, Nrp1, Cdh13, Epas1, Se...
# 25  GO:BP  2.239196e-03  Pcsk5, Hapln1, Emp2, Chst2, Ccn3, Ntn1, Mpz, P...
# 26  GO:BP  2.511856e-03  Pcsk5, Htra1, Grb14, Ltbp1, Ptgfr, Nrp1, Cdh13...
# 27  GO:BP  2.593800e-03         Qsox1, Pxdn, Efemp2, Emilin1, Phldb2, Has2
# 28  GO:BP  3.369174e-03  Aldh1a1, Pcsk5, Cpe, Emp2, Acta2, Ccn3, Ntn1, ...
# 29  GO:BP  3.627118e-03  Adamts17, Qsox1, Adamtsl3, Pxdn, Matn3, Efemp2...
# 30  GO:BP  3.627118e-03  Adamts17, Qsox1, Adamtsl3, Pxdn, Matn3, Efemp2...
# 31  GO:BP  3.807994e-03  Adamts17, Qsox1, Adamtsl3, Pxdn, Matn3, Efemp2...
# 32  GO:BP  4.590861e-03  Cntn6, Pcsk5, Cpe, Emp2, Htra1, Igfbp3, Tril, ...
# 33  GO:BP  5.596053e-03  Pcsk5, Igfbp3, Ccn3, Ntn1, Mag, Nrp1, Cdh13, N...
# 34  GO:BP  5.793466e-03  Cntn6, Pcsk5, Emp2, Htra1, Igfbp3, Tril, A2m, ...
# 35  GO:BP  6.069471e-03  Prss12, Pcsk5, Cpe, Emp2, Clca4l, Myo1d, Ccn3,...
# 36  GO:CC  7.249040e-03  Prss12, Pcsk5, Myo1d, Serpini1, Sncg, Dpysl5, ...
# 37  GO:BP  9.454179e-03  Emp2, Nrp1, Slit2, Met, Rhoj, Mef2c, Vash1, Wn...
# 38  GO:BP  1.605327e-02                                 Slit2, Atf5, Wnt5a
# 39  GO:BP  1.664073e-02  Ntn1, Mag, Nrp1, Slit2, Dpysl5, Pfn2, Sema3g, ...
# 40  GO:BP  1.977578e-02  Aldh1a1, Ntn1, Nrp1, Nrp2, Slit2, Lrp2, Cd151,...
# 41  GO:BP  1.990048e-02  Pcsk5, Emp2, Cdh13, Efemp2, Emilin1, Phldb2, I...
# 42  GO:BP  2.150719e-02  Gldc, Aldh1a1, Pcsk5, Ccn3, Grb14, Ntn1, Ptgfr...
# 43  GO:BP  2.413499e-02  Pcsk5, Htra1, Ltbp1, Nrp1, Nrp2, Slit2, Snx6, ...
# 44  GO:BP  2.587259e-02  Aldh1a1, Pcsk5, Emp2, Ntn1, Tent5c, Nrp1, Epas...
# 45  GO:CC  2.708075e-02  Emp2, Tnik, Lrp2, Gja1, Itga8, Cldnd1, Vash1, ...
# 46  GO:BP  2.756078e-02                           Nrp1, Nrp2, Slit2, Wnt5a
# 47  GO:BP  2.756078e-02                           Nrp1, Nrp2, Slit2, Wnt5a
# 48  GO:CC  2.845480e-02  Tex101, Qsox1, Cpe, Chst2, Slc9a9, Snx6, Pam, ...
# 49  GO:BP  2.924583e-02  Cntn6, Pcsk5, Emp2, Htra1, Igfbp3, Ccn3, Grb14...
# 50  GO:BP  2.957141e-02  Cntn6, Pcsk5, Emp2, Htra1, Igfbp3, Ccn3, Grb14...
# 51  GO:BP  3.275634e-02  Zpld1, Cntn6, Gldc, Aldh1a1, Pcsk5, Cpe, Emp2,...
# 52  GO:CC  4.302447e-02                         Myo1d, Mag, Serinc5, Pals1
# 53  GO:BP  4.558853e-02                           Ntn1, Nrp2, Slit2, Wnt5a
# 54  GO:CC  4.875039e-02  Parm1, Nrp1, Slc9a9, Snx6, Tpcn1, Numb, Zfyve2...
