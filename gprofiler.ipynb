# %%
import os
import pandas as pd
import requests
from RAG_workflow import initialize_gene_list, extract_gene_descriptions

def query_gprofiler_rest(genes, organism="rnorvegicus", user_threshold=0.05):
    url = "https://biit.cs.ut.ee/gprofiler/api/gost/profile/"
    sources = ["GO:BP", "GO:MF", "GO:CC", "KEGG", "REAC"]
    payload = {
        "organism": organism,
        "query": genes,
        "user_threshold": user_threshold,
        "sources": sources,
        "significance_threshold_method": "g_SCS",
        "no_iea": False,
        "domain_scope": "annotated",
        "output": "json",
        "no_evidences": False
    }
    headers = {"User-Agent": "FullPythonRequest"}
    response = requests.post(url, json=payload, headers=headers)
    response.raise_for_status()
    data = response.json()
    
    # Replicate the package's transformation of the intersections field:
    if not payload.get("no_evidences", True):
        meta = data.get("meta", {})
        if meta and "query_metadata" in meta and "genes_metadata" in meta:
            reverse_mappings = {}
            # Build reverse mapping for each query in the metadata
            queries = meta["query_metadata"]["queries"].keys()
            for query in queries:
                mapping = meta["genes_metadata"]["query"][query]["mapping"]
                reverse_mapping = {}
                for k, v in mapping.items():
                    if len(v) == 1:
                        reverse_mapping[v[0]] = k
                    else:
                        for i in v:
                            reverse_mapping[i] = i
                reverse_mappings[query] = reverse_mapping
            # Update each result's intersections to contain gene names
            for result in data["result"]:
                query_id = result["query"]
                if query_id not in meta["genes_metadata"]["query"]:
                    continue
                mapping = reverse_mappings[query_id]
                ens_genes = meta["genes_metadata"]["query"][query_id]["ensgs"]
                gene_names = [mapping.get(gene_id, gene_id) for gene_id in ens_genes]
                # Replace each truthy value in intersections with the corresponding gene name
                result["evidences"] = [ev for ev in result["intersections"] if ev]
                result["intersections"] = [gene for ev, gene in zip(result["intersections"], gene_names) if ev]
    
    df = pd.DataFrame(data["result"])
    return df

def flatten_list(nested_list):
    """Recursively flattens a nested list."""
    flat = []
    for item in nested_list:
        if isinstance(item, list):
            flat.extend(flatten_list(item))
        else:
            flat.append(item)
    return flat

def filter_best_per_parent(df):
    required_cols = {'p_value', 'parents', 'native'}
    if not required_cols.issubset(df.columns):
        return df
    df_sorted = df.sort_values(by='p_value', ascending=True).reset_index(drop=True)
    kept_terms = set()
    rows_to_keep = []
    for idx, row in df_sorted.iterrows():
        term_id = row['native']
        parent_ids = row['parents'] if isinstance(row['parents'], list) else []
        if any(parent in kept_terms for parent in parent_ids):
            continue
        rows_to_keep.append(idx)
        kept_terms.add(term_id)
    return df_sorted.loc[rows_to_keep].sort_values(by='p_value', ascending=True)

if __name__ == "__main__":
    gene_list_string, regulation, num_genes = initialize_gene_list()
    print(f"Number of genes: {num_genes}")
    gene_descriptions = extract_gene_descriptions(gene_list_string)
    
    genes = [gene.strip() for gene_list in gene_list_string.split(',') 
             for gene in gene_list.split() if gene.strip()]
    
    if genes:
        try:
            # Query g:Profiler using the REST API
            df_api = query_gprofiler_rest(genes=genes, organism="rnorvegicus", user_threshold=0.05)
            
            # Filter for significant results (p-value < 0.05)
            df_api_sig = df_api[df_api["p_value"] < 0.05].copy()
            
            # Filter best results per parent term
            df_api_best = filter_best_per_parent(df_api_sig)
            
            # Rename columns as desired
            df_api_best.rename(columns={
                "name": "Pathway", 
                "native": "annotation term", 
                "p_value": "p-value"
            }, inplace=True)
            
            # Build a 'genes' column from intersections, flattening nested lists if needed
            if "intersections" in df_api_best.columns:
                df_api_best['genes'] = df_api_best['intersections'].apply(
                    lambda x: ', '.join(map(str, flatten_list(x))) if isinstance(x, list) else str(x) if pd.notnull(x) else ''
                )
            else:
                df_api_best['genes'] = ''
            
            # Final DataFrame with desired columns:
            df_final = df_api_best[["Pathway", "description", "annotation term", "source", "p-value", "genes"]]
            
            output_path = "./output/text_files/ground_truth_pathways.txt"
            df_final[["Pathway", "annotation term", "genes"]].to_csv(output_path, sep="\t", index=False)
            print(f"Output written to {output_path}")
            
        except requests.HTTPError as e:
            print(f"HTTP error occurred: {e}")
        except Exception as e:
            print(f"An error occurred: {e}")
# Out:
# Number of genes: 250
# Total genes to process: 250
# Genes: {'Sncg', 'Nes', 'Ddx1', 'Prss23', 'Cdh13', 'Cep295nl', 'Sema3g', 'Adamts17', 'Grb14', 'Mfap5', 'Cd9', 'Tuba4a', 'Id2', 'Tspan5', 'Vps8', 'Htra1', 'Gprc5a', 'Agpat5', 'Zfyve28', 'Gcnt1', 'Pfn2', 'Acap2', 'Pgm1', 'Epas1', 'Dyrk1a', 'Cldnd1', 'Mageb16', 'Ppp1r36', 'Mal', 'Pappa', 'Cpe', 'Cntn6', 'Fhod3', 'Klhl29', 'ENSRNOG00000063649', 'Srgap1', 'Slc22a17', 'Cers6', 'Sbspon', 'Emilin1', 'Col11a1', 'Slco3a1', 'Trim35', 'Hsp90aa1', 'Nrp1', 'Tnik', 'Klhdc2', 'Gtf2e1', 'Ccn3', 'Cggbp1', 'Poglut1', 'Steap2', 'Ccn4', 'Itga7', 'Slit2', 'Acta2', 'Prkar2b', 'Aif1l', 'Prx', 'Scn7a', 'Cdca7l', 'Hapln1', 'Dpysl5', 'Runx3', 'Bace2', 'Arsb', 'Ckap4', 'Ppp1r14c', 'Mag', 'Gypc', 'Septin4', 'Marveld1', 'A2m', 'C1qtnf1', 'Riox2', 'Gldn', 'Dhrs1', 'Chst2', 'Adamtsl3', 'Zfp518a', 'Numb', 'Hmx3', 'Pnpt1', 'Magea9', 'Olfml1', 'Sema4f', 'Met', 'Snx4', 'Tf', 'Ntn1', 'Krtap1-5', 'Alpl', 'Gnai1', 'Map1lc3a', 'Atf5', 'Defb29', 'Ebf1', 'Col9a3', 'Hs6st1', 'Septin5', 'Psmd2', 'Vopp1', 'Matn3', 'Papola', 'Lef1', 'Drp2', 'Fbxo11', 'Ano5', 'Tagln', 'Bgn', 'Cd151', 'Ryr3', 'Serpini1', 'Ifnar1', 'Ghr', 'Inpp5a', 'Rab10', 'Asap1', 'Rcn3', 'Kif1a', 'Sipa1l1', 'Zpld1', 'Tspan4', 'Prss12', 'Gprc5b', 'Lrp2', 'Robo2', 'Icoslg', 'Pkp1', 'Manba', 'St3gal5', 'Emp2', 'Cldn19', 'Serpinf1', 'Hs6st2', 'Tent5c', 'Prkd3', 'Qsox1', 'Plxnb1', 'Fth1', 'Col20a1', 'Tnfrsf1a', 'Ptrh1', 'Ptgfr', 'Slc35a2', 'Hspa12a', 'Fut10', 'Efna5', 'Mpz', 'Msh2', 'Arsg', 'Tmem26', 'Ppfia4', 'Eif2ak2', 'Has2', 'Clca4l', 'Cxcl14', 'Tpcn1', 'Msi1', 'Timp1', 'Tril', 'Ppard', 'Rrm2', 'Aff3', 'Frrs1', 'Itpripl1', 'Mef2c', 'Serinc5', 'Stard13', 'Mybl1', 'Col8a2', 'Selplg', 'Nfatc1', 'Steap1', 'Vash1', 'Aldh1a1', 'Wnt5a', 'Atf3', 'Olfm2', 'Abcb4', 'Efemp2', 'Adamtsl1', 'Pam', 'Magea4', 'Psap', 'Parp14', 'Stk39', 'Apod', 'Lrrtm3', 'Igf2bp2', 'Nrp2', 'Myo1d', 'Phldb2', 'Itga8', 'Fam20c', 'Slc39a13', 'Sqor', 'Magec2l1', 'Taf9b', 'Pcsk5', 'P2ry2', 'Lifr', 'Cxcl12', 'Tubb4a', 'Chmp2b', 'Ltbp1', 'Aig1', 'Cpsf2', 'Smc6', 'Nlrp1a', 'Cenpo', 'Gldc', 'Igfbp3', 'Piezo2', 'Cobll1', 'Snx6', 'Gpnmb', 'Hadhb', 'Pltp', 'Pals1', 'Ctbs', 'Dpysl3', 'Ecel1', 'Synpr', 'Klf9', 'Man1a1', 'Slitrk6', 'Nek9', 'Cpm', 'Tex101', 'Vrk1', 'Rnf144a', 'Ighm', 'Nampt', 'Abca8a', 'Pmp22', 'ENSRNOG00000062503', 'Gja1', 'Sgpl1', 'Sumo3', 'Rhoj', 'Ppm1f', 'Peg3', 'Col15a1', 'Vps26c', 'Tbccd1', 'Parm1', 'Nrbp1', 'Pxdn', 'Slc9a9'}
# The following genes were not found in the gene data file: ENSRNOG00000063649, ENSRNOG00000062503
# Output written to ./output/text_files/ground_truth_pathways.txt

# %%
df_final
# Out:
#                                               Pathway  \
# 0                                      cell periphery
# 1                    multicellular organismal process
# 2                                extracellular region
# 4                         regulation of cell motility
# 6                                  system development
# 7                            regulation of locomotion
# 9                                          locomotion
# 10                   anatomical structure development
# 11                                     cell migration
# 12                                            vesicle
# 14                              developmental process
# 15                                      cell motility
# 16                                    protein binding
# 18                                endomembrane system
# 20                      response to external stimulus
# 21                               extracellular matrix
# 25          positive regulation of biological process
# 26                  Extracellular matrix organization
# 27                                      Axon guidance
# 28                                          cytoplasm
# 33                         blood vessel morphogenesis
# 37                                           membrane
# 39   enzyme-linked receptor protein signaling pathway
# 41                                   integrin binding
# 46                                 tube morphogenesis
# 48                                      cell adhesion
# 49                    response to endogenous stimulus
# 50                      extracellular matrix assembly
# 51                   regulation of biological quality
# 52                  extracellular matrix organization
# 53      external encapsulating structure organization
# 54               extracellular structure organization
# 56            cell surface receptor signaling pathway
# 57      regulation of cellular component organization
# 58                 regulation of response to stimulus
# 60                                       localization
# 61                        somatodendritic compartment
# 63           regulation of endothelial cell migration
# 66             olfactory bulb interneuron development
# 67  negative regulation of cell projection organiz...
# 68                               tissue morphogenesis
# 69                               cell-matrix adhesion
# 71                               response to chemical
# 72        cellular response to growth factor stimulus
# 73                                 embryo development
# 75                                apical part of cell
# 76           axon extension involved in axon guidance
# 77  neuron projection extension involved in neuron...
# 78                     bounding membrane of organelle
# 81                            regulation of signaling
# 82                   regulation of cell communication
# 84                               response to stimulus
# 87                                      myelin sheath
# 88                                negative chemotaxis
# 90                                     early endosome
#
#                                           description     annotation term  \
# 0   "The broad region around and including the pla...          GO:0071944
# 1   "Any biological process, occurring at the leve...          GO:0032501
# 2   "The space external to the outermost structure...          GO:0005576
# 4   "Any process that modulates the frequency, rat...          GO:2000145
# 6   "The process whose specific outcome is the pro...          GO:0048731
# 7   "Any process that modulates the frequency, rat...          GO:0040012
# 9   "Self-propelled movement of a cell or organism...          GO:0040011
# 10  "The biological process whose specific outcome...          GO:0048856
# 11  "The controlled self-propelled movement of a c...          GO:0016477
# 12  "Any small, fluid-filled, spherical organelle ...          GO:0031982
# 14  "A biological process whose specific outcome i...          GO:0032502
# 15  "Any process involved in the controlled self-p...          GO:0048870
# 16          "Binding to a protein." [GOC:go_curators]          GO:0005515
# 18  "A collection of membranous structures involve...          GO:0012505
# 20  "Any process that results in a change in state...          GO:0009605
# 21  "A structure lying external to one or more cel...          GO:0031012
# 25  "Any process that activates or increases the f...          GO:0048518
# 26                  Extracellular matrix organization  REAC:R-RNO-1474244
# 27                                      Axon guidance          KEGG:04360
# 28  "The contents of a cell excluding the plasma m...          GO:0005737
# 33  "The process in which the anatomical structure...          GO:0048514
# 37  "A lipid bilayer along with all the proteins a...          GO:0016020
# 39  "The series of molecular signals initiated by ...          GO:0007167
# 41                "Binding to an integrin." [GOC:ceb]          GO:0005178
# 46  "The process in which the anatomical structure...          GO:0035239
# 48  "The attachment of a cell, either to another c...          GO:0007155
# 49  "Any process that results in a change in state...          GO:0009719
# 50  "The aggregation, arrangement and bonding toge...          GO:0085029
# 51  "Any process that modulates a qualitative or q...          GO:0065008
# 52  "A process that is carried out at the cellular...          GO:0030198
# 53  "A process that is carried out at the cellular...          GO:0045229
# 54  "A process that is carried out at the cellular...          GO:0043062
# 56  "The series of molecular signals initiated by ...          GO:0007166
# 57  "Any process that modulates the frequency, rat...          GO:0051128
# 58  "Any process that modulates the frequency, rat...          GO:0048583
# 60  "Any process in which a cell, a substance, or ...          GO:0051179
# 61  "The region of a neuron that includes the cell...          GO:0036477
# 63  "Any process that modulates the rate, frequenc...          GO:0010594
# 66  "The process whose specific outcome is the pro...          GO:0021891
# 67  "Any process that stops, prevents, or reduces ...          GO:0031345
# 68  "The process in which the anatomical structure...          GO:0048729
# 69  "The binding of a cell to the extracellular ma...          GO:0007160
# 71  "Any process that results in a change in state...          GO:0042221
# 72  "Any process that results in a change in state...          GO:0071363
# 73  "The process whose specific outcome is the pro...          GO:0009790
# 75  "The region of a polarized cell that forms a t...          GO:0045177
# 76  "The long distance growth of a single cell pro...          GO:0048846
# 77  "Any neuron projection extension that is invol...          GO:1902284
# 78  "The lipid bilayer that forms the outer-most l...          GO:0098588
# 81  "Any process that modulates the frequency, rat...          GO:0023051
# 82  "Any process that modulates the frequency, rat...          GO:0010646
# 84  "Any process that results in a change in state...          GO:0050896
# 87  "An electrically insulating fatty layer that s...          GO:0043209
# 88  "The directed movement of a motile cell or org...          GO:0050919
# 90  "A membrane-bounded organelle that receives in...          GO:0005769
#
#    source       p-value                                              genes
# 0   GO:CC  4.299074e-13  Cntn6, Prss12, Tex101, Sema4f, Hapln1, Parm1, ...
# 1   GO:BP  3.928781e-10  Aldh1a1, Pcsk5, Cpe, Col9a3, Emp2, Acta2, Igfb...
# 2   GO:CC  2.623669e-09  Prss12, Pcsk5, Tex101, Qsox1, Htra1, Igfbp3, A...
# 4   GO:BP  1.567922e-08  Pcsk5, Tex101, Emp2, Chst2, Igfbp3, Ccn3, Ntn1...
# 6   GO:BP  2.075100e-08  Aldh1a1, Pcsk5, Cpe, Col9a3, Emp2, Acta2, Ccn3...
# 7   GO:BP  4.528831e-08  Pcsk5, Tex101, Emp2, Chst2, Igfbp3, Ccn3, Ntn1...
# 9   GO:BP  9.629089e-08  Pcsk5, Tex101, Emp2, Chst2, Igfbp3, Ccn3, Ntn1...
# 10  GO:BP  1.221614e-07  Aldh1a1, Pcsk5, Cpe, Col9a3, Emp2, Acta2, Htra...
# 11  GO:BP  3.510191e-07  Pcsk5, Emp2, Chst2, Igfbp3, Ccn3, Ntn1, Cxcl14...
# 12  GO:CC  4.542548e-07  Prss12, Tex101, Qsox1, Cpe, Parm1, Emp2, Synpr...
# 14  GO:BP  5.691427e-07  Aldh1a1, Pcsk5, Cpe, Col9a3, Emp2, Acta2, Htra...
# 15  GO:BP  9.196980e-07  Pcsk5, Tex101, Emp2, Chst2, Igfbp3, Ccn3, Ntn1...
# 16  GO:MF  1.083946e-06  Cntn6, Cobll1, Sema4f, Cpe, Tuba4a, Emp2, Acta...
# 18  GO:CC  1.211521e-06  Pcsk5, Tex101, Qsox1, Sema4f, Cpe, Parm1, Emp2...
# 20  GO:BP  2.297099e-06  Zpld1, Acta2, Tril, A2m, Ccn3, Defb29, Ntn1, P...
# 21  GO:CC  2.362395e-06  Hapln1, Ltbp1, Ntn1, Mfap5, Pxdn, Matn3, Efemp...
# 25  GO:BP  7.908000e-06  Cntn6, Aldh1a1, Pcsk5, Emp2, Chst2, Igfbp3, Tr...
# 26   REAC  8.642243e-06  Hapln1, Col9a3, A2m, Cep295nl, Mfap5, Pxdn, Ma...
# 27   KEGG  1.423045e-05  Sema4f, Ntn1, Srgap1, Nrp1, Robo2, Slit2, Gnai...
# 28  GO:CC  2.970568e-05  Prss12, Pcsk5, Tex101, Qsox1, Sema4f, Cpe, Par...
# 33  GO:BP  5.417253e-05  Emp2, Ccn3, Pxdn, Nrp1, Cdh13, Epas1, Serpinf1...
# 37  GO:CC  5.396448e-04  Cntn6, Prss12, Pcsk5, Tex101, Qsox1, Sema4f, C...
# 39  GO:BP  7.101388e-04  Htra1, Igfbp3, Ccn3, Grb14, Ltbp1, Nrp1, Cdh13...
# 41  GO:MF  9.228835e-04  Emp2, Ccn3, Tspan4, Cd9, Emilin1, Cd151, Cxcl1...
# 46  GO:BP  1.744178e-03  Emp2, Ccn3, Ntn1, Pxdn, Nrp1, Cdh13, Epas1, Se...
# 48  GO:BP  2.239196e-03  Pcsk5, Hapln1, Emp2, Chst2, Ccn3, Ntn1, Mpz, P...
# 49  GO:BP  2.511856e-03  Pcsk5, Htra1, Grb14, Ltbp1, Ptgfr, Nrp1, Cdh13...
# 50  GO:BP  2.593800e-03         Qsox1, Pxdn, Efemp2, Emilin1, Phldb2, Has2
# 51  GO:BP  3.369174e-03  Aldh1a1, Pcsk5, Cpe, Emp2, Acta2, Ccn3, Ntn1, ...
# 52  GO:BP  3.627118e-03  Adamts17, Qsox1, Adamtsl3, Pxdn, Matn3, Efemp2...
# 53  GO:BP  3.627118e-03  Adamts17, Qsox1, Adamtsl3, Pxdn, Matn3, Efemp2...
# 54  GO:BP  3.807994e-03  Adamts17, Qsox1, Adamtsl3, Pxdn, Matn3, Efemp2...
# 56  GO:BP  4.590861e-03  Cntn6, Pcsk5, Cpe, Emp2, Htra1, Igfbp3, Tril, ...
# 57  GO:BP  5.596053e-03  Pcsk5, Igfbp3, Ccn3, Ntn1, Mag, Nrp1, Cdh13, N...
# 58  GO:BP  5.793466e-03  Cntn6, Pcsk5, Emp2, Htra1, Igfbp3, Tril, A2m, ...
# 60  GO:BP  6.069471e-03  Prss12, Pcsk5, Cpe, Emp2, Clca4l, Myo1d, Ccn3,...
# 61  GO:CC  7.249040e-03  Prss12, Pcsk5, Myo1d, Serpini1, Sncg, Dpysl5, ...
# 63  GO:BP  9.454179e-03  Emp2, Nrp1, Slit2, Met, Rhoj, Mef2c, Vash1, Wn...
# 66  GO:BP  1.605327e-02                                 Slit2, Atf5, Wnt5a
# 67  GO:BP  1.664073e-02  Ntn1, Mag, Nrp1, Slit2, Dpysl5, Pfn2, Sema3g, ...
# 68  GO:BP  1.977578e-02  Aldh1a1, Ntn1, Nrp1, Nrp2, Slit2, Lrp2, Cd151,...
# 69  GO:BP  1.990048e-02  Pcsk5, Emp2, Cdh13, Efemp2, Emilin1, Phldb2, I...
# 71  GO:BP  2.150719e-02  Gldc, Aldh1a1, Pcsk5, Ccn3, Grb14, Ntn1, Ptgfr...
# 72  GO:BP  2.413499e-02  Pcsk5, Htra1, Ltbp1, Nrp1, Nrp2, Slit2, Snx6, ...
# 73  GO:BP  2.587259e-02  Aldh1a1, Pcsk5, Emp2, Ntn1, Tent5c, Nrp1, Epas...
# 75  GO:CC  2.708075e-02  Emp2, Tnik, Lrp2, Gja1, Itga8, Cldnd1, Vash1, ...
# 76  GO:BP  2.756078e-02                           Nrp1, Nrp2, Slit2, Wnt5a
# 77  GO:BP  2.756078e-02                           Nrp1, Nrp2, Slit2, Wnt5a
# 78  GO:CC  2.845480e-02  Tex101, Qsox1, Cpe, Chst2, Slc9a9, Snx6, Pam, ...
# 81  GO:BP  2.924583e-02  Cntn6, Pcsk5, Emp2, Htra1, Igfbp3, Ccn3, Grb14...
# 82  GO:BP  2.957141e-02  Cntn6, Pcsk5, Emp2, Htra1, Igfbp3, Ccn3, Grb14...
# 84  GO:BP  3.275634e-02  Zpld1, Cntn6, Gldc, Aldh1a1, Pcsk5, Cpe, Emp2,...
# 87  GO:CC  4.302447e-02                         Myo1d, Mag, Serinc5, Pals1
# 88  GO:BP  4.558853e-02                           Ntn1, Nrp2, Slit2, Wnt5a
# 90  GO:CC  4.875039e-02  Parm1, Nrp1, Slc9a9, Snx6, Tpcn1, Numb, Zfyve2...
